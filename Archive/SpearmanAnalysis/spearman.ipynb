# %%
# --- Kd avg (nM) values for each mutation per antibody ---

kd_values = {
    "C143": {
        "V29F": 139.9,
        "K32Y": 31772.0,
        "L51Y": 175.5,
        "A77T": 165.4,
        "G91A": 171.3
    },
    "S309": {
        "P28T": 3.233,
        "T77N": 2.679,
        "G79A": 3.175,
        "R84S": 2.759,
        "R85S": 3.214,
        "R87T": 2.243
    },
    "MEDI8852": {
        "D27F": 1.1051,
        "V35Y": 0.82875,
        "S44G": 0.6557,
        "T53I": 0.71885,
        "W59S": 0.91145,
        "E65P": 0.3973,
        "N74S": 0.6149,
        "M117Y": 0.42905
    }
}
# Out:
# === Kd Avg Values (nM) ===
#
# C143
#   V29F: 139.9
#   K32Y: 31772.0
#   L51Y: 175.5
#   A77T: 165.4
#   G91A: 171.3
#
# S309
#   P28T: 3.233
#   T77N: 2.679
#   G79A: 3.175
#   R84S: 2.759
#   R85S: 3.214
#   R87T: 2.243
#
# MEDI8852
#   D27F: 1.1051
#   V35Y: 0.82875
#   S44G: 0.6557
#   T53I: 0.71885
#   W59S: 0.91145
#   E65P: 0.3973
#   N74S: 0.6149
#   M117Y: 0.42905

# %%
import pandas as pd
import os
from collections import defaultdict

# Mutation definitions
mutations = {
    "MEDI8852": ["D27F", "V35Y", "S44G", "T53I", "W59S", "E65P", "N74S", "M117Y"],
    "C143": ["V29F", "K32Y", "L51Y", "D57T", "A77T", "G91A"],
    "S309": ["P28T", "T77N", "G79A", "R84S", "R85S", "R87T"]
}

# Base folder containing subfolders for each antibody
base_path = "./LLR_data"  # <--- change this to your actual data root

# Helper to extract numeric position
def get_position(mutation):
    return int(''.join(filter(str.isdigit, mutation)))

# Helper to extract clean model name
def extract_model_name(file_name, antibody):
    name = file_name.replace(f"{antibody}_", "")
    name = name.replace("facebook_", "").replace("hugohrban_", "")
    name = name.replace("_llr.csv", "")
    return name

# Result storage: {antibody -> {mutation -> [(model_name, llr), ...]}}
llr_results = defaultdict(lambda: defaultdict(list))

# Process each antibody
for antibody, muts in mutations.items():
    folder_path = os.path.join(base_path, antibody)
    if not os.path.isdir(folder_path):
        print(f"Folder not found: {folder_path}")
        continue

    for file_name in os.listdir(folder_path):
        if not file_name.endswith(".csv"):
            continue

        file_path = os.path.join(folder_path, file_name)
        model_name = extract_model_name(file_name, antibody)

        df = pd.read_csv(file_path)

        for mut in muts:
            position = get_position(mut)
            col_index = position - 1  # assuming 1-based indexing

            try:
                llr = df.iloc[0, col_index]
                llr_results[antibody][mut].append((model_name, llr))
            except IndexError:
                llr_results[antibody][mut].append((model_name, "IndexError"))

# Print the results
for antibody, mut_values in llr_results.items():
    print(f"\n{antibody}")
    for mut, entries in mut_values.items():
        print(f"  {mut}:")
        for model_name, llr in entries:
            print(f"    {model_name}: {llr}")
# Out:
# MEDI8852
#   D27F:
#     esm1b_t33_650M_UR50S: -5.641163751482964
#     esm2_t33_650M_UR50D: -7.028448010329157
#     esm2_t36_3B_UR50D: -7.59190165437758
#     progen2-large: -3.1158015727996826
#     esm2_t6_8M_UR50D: 0.116243839263916
#     progen2-medium: -1.8530731201171875
#     progen2-oas: -3.7029038071632394
#     progen2-small: -1.0269012451171875
#   V35Y:
#     esm1b_t33_650M_UR50S: 0.0
#     esm2_t33_650M_UR50D: 0.0
#     esm2_t36_3B_UR50D: 0.0
#     progen2-large: 1.0504934787750244
#     esm2_t6_8M_UR50D: 0.0
#     progen2-medium: 0.2810592651367187
#     progen2-oas: 3.1482010185718536
#     progen2-small: 0.5063629150390625
#   S44G:
#     esm1b_t33_650M_UR50S: -2.562242195010185
#     esm2_t33_650M_UR50D: -3.677783578634262
#     esm2_t36_3B_UR50D: -0.6646530628204346
#     progen2-large: -2.5922261476516724
#     esm2_t6_8M_UR50D: -0.6344132423400879
#     progen2-medium: -0.1648712158203125
#     progen2-oas: -4.8417203687131405
#     progen2-small: 0.0788421630859375
#   T53I:
#     esm1b_t33_650M_UR50S: 0.1550445556640625
#     esm2_t33_650M_UR50D: -0.6892752647399902
#     esm2_t36_3B_UR50D: -1.242284893989563
#     progen2-large: -4.257756188511848
#     esm2_t6_8M_UR50D: 0.1460299491882324
#     progen2-medium: -1.1995849609375
#     progen2-oas: -3.7272873260080814
#     progen2-small: -3.393798828125
#   W59S:
#     esm1b_t33_650M_UR50S: -1.7811298370361328
#     esm2_t33_650M_UR50D: -2.191400170326233
#     esm2_t36_3B_UR50D: -1.5257891416549685
#     progen2-large: 1.124701976776123
#     esm2_t6_8M_UR50D: -0.6920413970947266
#     progen2-medium: 0.7976837158203125
#     progen2-oas: -7.999099262058735
#     progen2-small: 0.4402008056640625
#   E65P:
#     esm1b_t33_650M_UR50S: 0.0
#     esm2_t33_650M_UR50D: 0.0
#     esm2_t36_3B_UR50D: 0.0
#     progen2-large: -0.5837602615356445
#     esm2_t6_8M_UR50D: 0.0
#     progen2-medium: -0.2158355712890625
#     progen2-oas: -0.4160079956054687
#     progen2-small: 1.86407470703125
#   N74S:
#     esm1b_t33_650M_UR50S: -3.459799021482468
#     esm2_t33_650M_UR50D: -4.623093605041504
#     esm2_t36_3B_UR50D: -4.15341329574585
#     progen2-large: -0.554987907409668
#     esm2_t6_8M_UR50D: -1.299980640411377
#     progen2-medium: 0.0413510799407959
#     progen2-oas: -6.6986696273088455
#     progen2-small: -0.2878570556640625
#   M117Y:
#     esm1b_t33_650M_UR50S: -4.177235901355743
#     esm2_t33_650M_UR50D: -2.689128875732422
#     esm2_t36_3B_UR50D: -5.38529571890831
#     progen2-large: -1.822936534881592
#     esm2_t6_8M_UR50D: 0.2089123725891113
#     progen2-medium: 0.6510696411132812
#     progen2-oas: -3.766788244247437
#     progen2-small: 1.001007080078125
#
# C143
#   V29F:
#     esm1b_t33_650M_UR50S: -2.79415225982666
#     esm2_t36_3B_UR50D: -1.799311876296997
#     esm2_t6_8M_UR50D: -0.8836368322372437
#     progen2-large: -4.859659671783447
#     progen2-medium: -2.8656997680664062
#     progen2-oas: -4.392661809921265
#     progen2-small: -1.6372566223144531
#     esm2_t33_650M_UR50D: -2.781845569610596
#   K32Y:
#     esm1b_t33_650M_UR50S: -1.579371452331543
#     esm2_t36_3B_UR50D: 0.5073552131652832
#     esm2_t6_8M_UR50D: 0.3207173347473144
#     progen2-large: -1.2898483276367188
#     progen2-medium: 1.9193038940429688
#     progen2-oas: -3.030834436416626
#     progen2-small: 2.479522705078125
#     esm2_t33_650M_UR50D: -0.726287841796875
#   L51Y:
#     esm1b_t33_650M_UR50S: 0.1844387054443359
#     esm2_t36_3B_UR50D: 0.1065590381622314
#     esm2_t6_8M_UR50D: -0.8650480508804321
#     progen2-large: -2.116316318511963
#     progen2-medium: -1.5150604248046875
#     progen2-oas: -4.793731451034546
#     progen2-small: -1.253753662109375
#     esm2_t33_650M_UR50D: 0.1830966472625732
#   D57T:
#     esm1b_t33_650M_UR50S: -2.37833309173584
#     esm2_t36_3B_UR50D: -3.2020713686943054
#     esm2_t6_8M_UR50D: -0.5563249588012695
#     progen2-large: 1.8954730033874512
#     progen2-medium: 0.979255437850952
#     progen2-oas: 4.943763732910156
#     progen2-small: -1.7699203491210938
#     esm2_t33_650M_UR50D: -0.9912492036819458
#   A77T:
#     esm1b_t33_650M_UR50S: -5.575323671102524
#     esm2_t36_3B_UR50D: -3.12988018989563
#     esm2_t6_8M_UR50D: 0.0184929370880126
#     progen2-large: 0.0
#     progen2-medium: 0.0
#     progen2-oas: 0.0
#     progen2-small: 0.0
#     esm2_t33_650M_UR50D: -5.444222837686539
#   G91A:
#     esm1b_t33_650M_UR50S: -4.240588918328285
#     esm2_t36_3B_UR50D: -2.748996883630753
#     esm2_t6_8M_UR50D: -0.0231716632843017
#     progen2-large: 3.5077581889927387
#     progen2-medium: 4.076110932976008
#     progen2-oas: 4.116260731592774
#     progen2-small: 5.0421066312119365
#     esm2_t33_650M_UR50D: -4.709376364946365
#
# S309
#   P28T:
#     esm1b_t33_650M_UR50S: -6.59996223449707
#     esm2_t33_650M_UR50D: -8.155033215880394
#     esm2_t36_3B_UR50D: -5.83752915263176
#     progen2-large: 1.7470674514770508
#     esm2_t6_8M_UR50D: 0.4052150249481201
#     progen2-medium: 2.244819402694702
#     progen2-oas: -1.5819549560546875
#     progen2-small: 1.9216384887695312
#   T77N:
#     esm1b_t33_650M_UR50S: -2.1511270999908447
#     esm2_t33_650M_UR50D: -0.1294026374816894
#     esm2_t36_3B_UR50D: -2.2692296504974365
#     progen2-large: -3.3075919151306152
#     esm2_t6_8M_UR50D: -0.2499756813049316
#     progen2-medium: -1.4802095890045166
#     progen2-oas: -4.4311370849609375
#     progen2-small: -1.0657119750976562
#   G79A:
#     esm1b_t33_650M_UR50S: -5.091760650277138
#     esm2_t33_650M_UR50D: -4.706926383078098
#     esm2_t36_3B_UR50D: -5.714510156773031
#     progen2-large: 3.728068396449089
#     esm2_t6_8M_UR50D: -0.8298441171646118
#     progen2-medium: 4.374618358910084
#     progen2-oas: 3.453723818063736
#     progen2-small: 4.311412811279297
#   R84S:
#     esm1b_t33_650M_UR50S: -6.8031845688819885
#     esm2_t33_650M_UR50D: -13.400879786349831
#     esm2_t36_3B_UR50D: -10.77981158113107
#     progen2-large: -7.253823675215244
#     esm2_t6_8M_UR50D: -4.22419285774231
#     progen2-medium: -3.034904718399048
#     progen2-oas: -8.091511085629463
#     progen2-small: -1.7945632934570312
#   R85S:
#     esm1b_t33_650M_UR50S: 0.8564910888671875
#     esm2_t33_650M_UR50D: -0.8212335109710693
#     esm2_t36_3B_UR50D: -2.2128348350524902
#     progen2-large: -2.0606164932250977
#     esm2_t6_8M_UR50D: -0.7956664562225342
#     progen2-medium: -2.1872100830078125
#     progen2-oas: -3.593910217285156
#     progen2-small: -0.3753623962402344
#   R87T:
#     esm1b_t33_650M_UR50S: -7.639145337045193
#     esm2_t33_650M_UR50D: -8.459521709941328
#     esm2_t36_3B_UR50D: -9.745874010957778
#     progen2-large: -5.899165377020836
#     esm2_t6_8M_UR50D: -1.007752537727356
#     progen2-medium: -3.777686983346939
#     progen2-oas: -6.26036062836647
#     progen2-small: -0.18280029296875

# %%
# Kd avg values
kd_values = {
    "MEDI8852": {
        "D27F": 1.1051, "V35Y": 0.82875, "S44G": 0.6557, "T53I": 0.71885,
        "W59S": 0.91145, "E65P": 0.3973, "N74S": 0.6149, "M117Y": 0.42905
    },
    "C143": {
        "V29F": 139.9, "K32Y": 31772.0, "L51Y": 175.5, "D57T": None,
        "A77T": 165.4, "G91A": 171.3
    },
    "S309": {
        "P28T": 3.233, "T77N": 2.679, "G79A": 3.175, "R84S": 2.759,
        "R85S": 3.214, "R87T": 2.243
    }
}

# Create DataFrames
antibody_dfs = {}

for antibody, mut_data in llr_results.items():
    rows = []
    for mut, model_llrs in mut_data.items():
        kd = kd_values.get(antibody, {}).get(mut)
        for model_name, llr in model_llrs:
            if isinstance(llr, (float, int)):  # exclude errors or non-numeric
                rows.append({
                    "Model": model_name,
                    "Mutation": mut,
                    "LLR": llr,
                    "Kd_avg": kd
                })
    df = pd.DataFrame(rows)
    antibody_dfs[antibody] = df

pd.set_option("display.max_rows", None)

# Assign individual DataFrames
df_medi8852 = antibody_dfs["MEDI8852"]
df_c143 = antibody_dfs["C143"]
df_s309 = antibody_dfs["S309"]

print("\nMEDI8852 DataFrame:")
print(df_medi8852)

print("\nC143 DataFrame:")
print(df_c143)

print("\nS309 DataFrame:")
print(df_s309)
# Out:
# MEDI8852 DataFrame:
#                    Model Mutation       LLR   Kd_avg
# 0   esm1b_t33_650M_UR50S     D27F -5.641164  1.10510
# 1    esm2_t33_650M_UR50D     D27F -7.028448  1.10510
# 2      esm2_t36_3B_UR50D     D27F -7.591902  1.10510
# 3          progen2-large     D27F -3.115802  1.10510
# 4       esm2_t6_8M_UR50D     D27F  0.116244  1.10510
# 5         progen2-medium     D27F -1.853073  1.10510
# 6            progen2-oas     D27F -3.702904  1.10510
# 7          progen2-small     D27F -1.026901  1.10510
# 8   esm1b_t33_650M_UR50S     V35Y  0.000000  0.82875
# 9    esm2_t33_650M_UR50D     V35Y  0.000000  0.82875
# 10     esm2_t36_3B_UR50D     V35Y  0.000000  0.82875
# 11         progen2-large     V35Y  1.050493  0.82875
# 12      esm2_t6_8M_UR50D     V35Y  0.000000  0.82875
# 13        progen2-medium     V35Y  0.281059  0.82875
# 14           progen2-oas     V35Y  3.148201  0.82875
# 15         progen2-small     V35Y  0.506363  0.82875
# 16  esm1b_t33_650M_UR50S     S44G -2.562242  0.65570
# 17   esm2_t33_650M_UR50D     S44G -3.677784  0.65570
# 18     esm2_t36_3B_UR50D     S44G -0.664653  0.65570
# 19         progen2-large     S44G -2.592226  0.65570
# 20      esm2_t6_8M_UR50D     S44G -0.634413  0.65570
# 21        progen2-medium     S44G -0.164871  0.65570
# 22           progen2-oas     S44G -4.841720  0.65570
# 23         progen2-small     S44G  0.078842  0.65570
# 24  esm1b_t33_650M_UR50S     T53I  0.155045  0.71885
# 25   esm2_t33_650M_UR50D     T53I -0.689275  0.71885
# 26     esm2_t36_3B_UR50D     T53I -1.242285  0.71885
# 27         progen2-large     T53I -4.257756  0.71885
# 28      esm2_t6_8M_UR50D     T53I  0.146030  0.71885
# 29        progen2-medium     T53I -1.199585  0.71885
# 30           progen2-oas     T53I -3.727287  0.71885
# 31         progen2-small     T53I -3.393799  0.71885
# 32  esm1b_t33_650M_UR50S     W59S -1.781130  0.91145
# 33   esm2_t33_650M_UR50D     W59S -2.191400  0.91145
# 34     esm2_t36_3B_UR50D     W59S -1.525789  0.91145
# 35         progen2-large     W59S  1.124702  0.91145
# 36      esm2_t6_8M_UR50D     W59S -0.692041  0.91145
# 37        progen2-medium     W59S  0.797684  0.91145
# 38           progen2-oas     W59S -7.999099  0.91145
# 39         progen2-small     W59S  0.440201  0.91145
# 40  esm1b_t33_650M_UR50S     E65P  0.000000  0.39730
# 41   esm2_t33_650M_UR50D     E65P  0.000000  0.39730
# 42     esm2_t36_3B_UR50D     E65P  0.000000  0.39730
# 43         progen2-large     E65P -0.583760  0.39730
# 44      esm2_t6_8M_UR50D     E65P  0.000000  0.39730
# 45        progen2-medium     E65P -0.215836  0.39730
# 46           progen2-oas     E65P -0.416008  0.39730
# 47         progen2-small     E65P  1.864075  0.39730
# 48  esm1b_t33_650M_UR50S     N74S -3.459799  0.61490
# 49   esm2_t33_650M_UR50D     N74S -4.623094  0.61490
# 50     esm2_t36_3B_UR50D     N74S -4.153413  0.61490
# 51         progen2-large     N74S -0.554988  0.61490
# 52      esm2_t6_8M_UR50D     N74S -1.299981  0.61490
# 53        progen2-medium     N74S  0.041351  0.61490
# 54           progen2-oas     N74S -6.698670  0.61490
# 55         progen2-small     N74S -0.287857  0.61490
# 56  esm1b_t33_650M_UR50S    M117Y -4.177236  0.42905
# 57   esm2_t33_650M_UR50D    M117Y -2.689129  0.42905
# 58     esm2_t36_3B_UR50D    M117Y -5.385296  0.42905
# 59         progen2-large    M117Y -1.822937  0.42905
# 60      esm2_t6_8M_UR50D    M117Y  0.208912  0.42905
# 61        progen2-medium    M117Y  0.651070  0.42905
# 62           progen2-oas    M117Y -3.766788  0.42905
# 63         progen2-small    M117Y  1.001007  0.42905
#
# C143 DataFrame:
#                    Model Mutation       LLR   Kd_avg
# 0   esm1b_t33_650M_UR50S     V29F -2.794152    139.9
# 1      esm2_t36_3B_UR50D     V29F -1.799312    139.9
# 2       esm2_t6_8M_UR50D     V29F -0.883637    139.9
# 3          progen2-large     V29F -4.859660    139.9
# 4         progen2-medium     V29F -2.865700    139.9
# 5            progen2-oas     V29F -4.392662    139.9
# 6          progen2-small     V29F -1.637257    139.9
# 7    esm2_t33_650M_UR50D     V29F -2.781846    139.9
# 8   esm1b_t33_650M_UR50S     K32Y -1.579371  31772.0
# 9      esm2_t36_3B_UR50D     K32Y  0.507355  31772.0
# 10      esm2_t6_8M_UR50D     K32Y  0.320717  31772.0
# 11         progen2-large     K32Y -1.289848  31772.0
# 12        progen2-medium     K32Y  1.919304  31772.0
# 13           progen2-oas     K32Y -3.030834  31772.0
# 14         progen2-small     K32Y  2.479523  31772.0
# 15   esm2_t33_650M_UR50D     K32Y -0.726288  31772.0
# 16  esm1b_t33_650M_UR50S     L51Y  0.184439    175.5
# 17     esm2_t36_3B_UR50D     L51Y  0.106559    175.5
# 18      esm2_t6_8M_UR50D     L51Y -0.865048    175.5
# 19         progen2-large     L51Y -2.116316    175.5
# 20        progen2-medium     L51Y -1.515060    175.5
# 21           progen2-oas     L51Y -4.793731    175.5
# 22         progen2-small     L51Y -1.253754    175.5
# 23   esm2_t33_650M_UR50D     L51Y  0.183097    175.5
# 24  esm1b_t33_650M_UR50S     D57T -2.378333      NaN
# 25     esm2_t36_3B_UR50D     D57T -3.202071      NaN
# 26      esm2_t6_8M_UR50D     D57T -0.556325      NaN
# 27         progen2-large     D57T  1.895473      NaN
# 28        progen2-medium     D57T  0.979255      NaN
# 29           progen2-oas     D57T  4.943764      NaN
# 30         progen2-small     D57T -1.769920      NaN
# 31   esm2_t33_650M_UR50D     D57T -0.991249      NaN
# 32  esm1b_t33_650M_UR50S     A77T -5.575324    165.4
# 33     esm2_t36_3B_UR50D     A77T -3.129880    165.4
# 34      esm2_t6_8M_UR50D     A77T  0.018493    165.4
# 35         progen2-large     A77T  0.000000    165.4
# 36        progen2-medium     A77T  0.000000    165.4
# 37           progen2-oas     A77T  0.000000    165.4
# 38         progen2-small     A77T  0.000000    165.4
# 39   esm2_t33_650M_UR50D     A77T -5.444223    165.4
# 40  esm1b_t33_650M_UR50S     G91A -4.240589    171.3
# 41     esm2_t36_3B_UR50D     G91A -2.748997    171.3
# 42      esm2_t6_8M_UR50D     G91A -0.023172    171.3
# 43         progen2-large     G91A  3.507758    171.3
# 44        progen2-medium     G91A  4.076111    171.3
# 45           progen2-oas     G91A  4.116261    171.3
# 46         progen2-small     G91A  5.042107    171.3
# 47   esm2_t33_650M_UR50D     G91A -4.709376    171.3
#
# S309 DataFrame:
#                    Model Mutation        LLR  Kd_avg
# 0   esm1b_t33_650M_UR50S     P28T  -6.599962   3.233
# 1    esm2_t33_650M_UR50D     P28T  -8.155033   3.233
# 2      esm2_t36_3B_UR50D     P28T  -5.837529   3.233
# 3          progen2-large     P28T   1.747067   3.233
# 4       esm2_t6_8M_UR50D     P28T   0.405215   3.233
# 5         progen2-medium     P28T   2.244819   3.233
# 6            progen2-oas     P28T  -1.581955   3.233
# 7          progen2-small     P28T   1.921638   3.233
# 8   esm1b_t33_650M_UR50S     T77N  -2.151127   2.679
# 9    esm2_t33_650M_UR50D     T77N  -0.129403   2.679
# 10     esm2_t36_3B_UR50D     T77N  -2.269230   2.679
# 11         progen2-large     T77N  -3.307592   2.679
# 12      esm2_t6_8M_UR50D     T77N  -0.249976   2.679
# 13        progen2-medium     T77N  -1.480210   2.679
# 14           progen2-oas     T77N  -4.431137   2.679
# 15         progen2-small     T77N  -1.065712   2.679
# 16  esm1b_t33_650M_UR50S     G79A  -5.091761   3.175
# 17   esm2_t33_650M_UR50D     G79A  -4.706926   3.175
# 18     esm2_t36_3B_UR50D     G79A  -5.714510   3.175
# 19         progen2-large     G79A   3.728068   3.175
# 20      esm2_t6_8M_UR50D     G79A  -0.829844   3.175
# 21        progen2-medium     G79A   4.374618   3.175
# 22           progen2-oas     G79A   3.453724   3.175
# 23         progen2-small     G79A   4.311413   3.175
# 24  esm1b_t33_650M_UR50S     R84S  -6.803185   2.759
# 25   esm2_t33_650M_UR50D     R84S -13.400880   2.759
# 26     esm2_t36_3B_UR50D     R84S -10.779812   2.759
# 27         progen2-large     R84S  -7.253824   2.759
# 28      esm2_t6_8M_UR50D     R84S  -4.224193   2.759
# 29        progen2-medium     R84S  -3.034905   2.759
# 30           progen2-oas     R84S  -8.091511   2.759
# 31         progen2-small     R84S  -1.794563   2.759
# 32  esm1b_t33_650M_UR50S     R85S   0.856491   3.214
# 33   esm2_t33_650M_UR50D     R85S  -0.821234   3.214
# 34     esm2_t36_3B_UR50D     R85S  -2.212835   3.214
# 35         progen2-large     R85S  -2.060616   3.214
# 36      esm2_t6_8M_UR50D     R85S  -0.795666   3.214
# 37        progen2-medium     R85S  -2.187210   3.214
# 38           progen2-oas     R85S  -3.593910   3.214
# 39         progen2-small     R85S  -0.375362   3.214
# 40  esm1b_t33_650M_UR50S     R87T  -7.639145   2.243
# 41   esm2_t33_650M_UR50D     R87T  -8.459522   2.243
# 42     esm2_t36_3B_UR50D     R87T  -9.745874   2.243
# 43         progen2-large     R87T  -5.899165   2.243
# 44      esm2_t6_8M_UR50D     R87T  -1.007753   2.243
# 45        progen2-medium     R87T  -3.777687   2.243
# 46           progen2-oas     R87T  -6.260361   2.243
# 47         progen2-small     R87T  -0.182800   2.243

# %%
# Group by model name for each antibody
grouped_medi8852 = df_medi8852.groupby("Model")
grouped_c143 = df_c143.groupby("Model")
grouped_s309 = df_s309.groupby("Model")

# Example: print each model group for MEDI8852
print("\n=== Grouped by Model: MEDI8852 ===")
for model, group in grouped_medi8852:
    print(f"\nModel: {model}")
    print(group)

print("\n=== Grouped by Model: C143 ===")
for model, group in grouped_c143:
    print(f"\nModel: {model}")
    print(group)

print("\n=== Grouped by Model: S309 ===")
for model, group in grouped_s309:
    print(f"\nModel: {model}")
    print(group)
# Out:
# === Grouped by Model: MEDI8852 ===
#
# Model: esm1b_t33_650M_UR50S
#                    Model Mutation       LLR   Kd_avg
# 0   esm1b_t33_650M_UR50S     D27F -5.641164  1.10510
# 8   esm1b_t33_650M_UR50S     V35Y  0.000000  0.82875
# 16  esm1b_t33_650M_UR50S     S44G -2.562242  0.65570
# 24  esm1b_t33_650M_UR50S     T53I  0.155045  0.71885
# 32  esm1b_t33_650M_UR50S     W59S -1.781130  0.91145
# 40  esm1b_t33_650M_UR50S     E65P  0.000000  0.39730
# 48  esm1b_t33_650M_UR50S     N74S -3.459799  0.61490
# 56  esm1b_t33_650M_UR50S    M117Y -4.177236  0.42905
#
# Model: esm2_t33_650M_UR50D
#                   Model Mutation       LLR   Kd_avg
# 1   esm2_t33_650M_UR50D     D27F -7.028448  1.10510
# 9   esm2_t33_650M_UR50D     V35Y  0.000000  0.82875
# 17  esm2_t33_650M_UR50D     S44G -3.677784  0.65570
# 25  esm2_t33_650M_UR50D     T53I -0.689275  0.71885
# 33  esm2_t33_650M_UR50D     W59S -2.191400  0.91145
# 41  esm2_t33_650M_UR50D     E65P  0.000000  0.39730
# 49  esm2_t33_650M_UR50D     N74S -4.623094  0.61490
# 57  esm2_t33_650M_UR50D    M117Y -2.689129  0.42905
#
# Model: esm2_t36_3B_UR50D
#                 Model Mutation       LLR   Kd_avg
# 2   esm2_t36_3B_UR50D     D27F -7.591902  1.10510
# 10  esm2_t36_3B_UR50D     V35Y  0.000000  0.82875
# 18  esm2_t36_3B_UR50D     S44G -0.664653  0.65570
# 26  esm2_t36_3B_UR50D     T53I -1.242285  0.71885
# 34  esm2_t36_3B_UR50D     W59S -1.525789  0.91145
# 42  esm2_t36_3B_UR50D     E65P  0.000000  0.39730
# 50  esm2_t36_3B_UR50D     N74S -4.153413  0.61490
# 58  esm2_t36_3B_UR50D    M117Y -5.385296  0.42905
#
# Model: esm2_t6_8M_UR50D
#                Model Mutation       LLR   Kd_avg
# 4   esm2_t6_8M_UR50D     D27F  0.116244  1.10510
# 12  esm2_t6_8M_UR50D     V35Y  0.000000  0.82875
# 20  esm2_t6_8M_UR50D     S44G -0.634413  0.65570
# 28  esm2_t6_8M_UR50D     T53I  0.146030  0.71885
# 36  esm2_t6_8M_UR50D     W59S -0.692041  0.91145
# 44  esm2_t6_8M_UR50D     E65P  0.000000  0.39730
# 52  esm2_t6_8M_UR50D     N74S -1.299981  0.61490
# 60  esm2_t6_8M_UR50D    M117Y  0.208912  0.42905
#
# Model: progen2-large
#             Model Mutation       LLR   Kd_avg
# 3   progen2-large     D27F -3.115802  1.10510
# 11  progen2-large     V35Y  1.050493  0.82875
# 19  progen2-large     S44G -2.592226  0.65570
# 27  progen2-large     T53I -4.257756  0.71885
# 35  progen2-large     W59S  1.124702  0.91145
# 43  progen2-large     E65P -0.583760  0.39730
# 51  progen2-large     N74S -0.554988  0.61490
# 59  progen2-large    M117Y -1.822937  0.42905
#
# Model: progen2-medium
#              Model Mutation       LLR   Kd_avg
# 5   progen2-medium     D27F -1.853073  1.10510
# 13  progen2-medium     V35Y  0.281059  0.82875
# 21  progen2-medium     S44G -0.164871  0.65570
# 29  progen2-medium     T53I -1.199585  0.71885
# 37  progen2-medium     W59S  0.797684  0.91145
# 45  progen2-medium     E65P -0.215836  0.39730
# 53  progen2-medium     N74S  0.041351  0.61490
# 61  progen2-medium    M117Y  0.651070  0.42905
#
# Model: progen2-oas
#           Model Mutation       LLR   Kd_avg
# 6   progen2-oas     D27F -3.702904  1.10510
# 14  progen2-oas     V35Y  3.148201  0.82875
# 22  progen2-oas     S44G -4.841720  0.65570
# 30  progen2-oas     T53I -3.727287  0.71885
# 38  progen2-oas     W59S -7.999099  0.91145
# 46  progen2-oas     E65P -0.416008  0.39730
# 54  progen2-oas     N74S -6.698670  0.61490
# 62  progen2-oas    M117Y -3.766788  0.42905
#
# Model: progen2-small
#             Model Mutation       LLR   Kd_avg
# 7   progen2-small     D27F -1.026901  1.10510
# 15  progen2-small     V35Y  0.506363  0.82875
# 23  progen2-small     S44G  0.078842  0.65570
# 31  progen2-small     T53I -3.393799  0.71885
# 39  progen2-small     W59S  0.440201  0.91145
# 47  progen2-small     E65P  1.864075  0.39730
# 55  progen2-small     N74S -0.287857  0.61490
# 63  progen2-small    M117Y  1.001007  0.42905
#
# === Grouped by Model: C143 ===
#
# Model: esm1b_t33_650M_UR50S
#                    Model Mutation       LLR   Kd_avg
# 0   esm1b_t33_650M_UR50S     V29F -2.794152    139.9
# 8   esm1b_t33_650M_UR50S     K32Y -1.579371  31772.0
# 16  esm1b_t33_650M_UR50S     L51Y  0.184439    175.5
# 24  esm1b_t33_650M_UR50S     D57T -2.378333      NaN
# 32  esm1b_t33_650M_UR50S     A77T -5.575324    165.4
# 40  esm1b_t33_650M_UR50S     G91A -4.240589    171.3
#
# Model: esm2_t33_650M_UR50D
#                   Model Mutation       LLR   Kd_avg
# 7   esm2_t33_650M_UR50D     V29F -2.781846    139.9
# 15  esm2_t33_650M_UR50D     K32Y -0.726288  31772.0
# 23  esm2_t33_650M_UR50D     L51Y  0.183097    175.5
# 31  esm2_t33_650M_UR50D     D57T -0.991249      NaN
# 39  esm2_t33_650M_UR50D     A77T -5.444223    165.4
# 47  esm2_t33_650M_UR50D     G91A -4.709376    171.3
#
# Model: esm2_t36_3B_UR50D
#                 Model Mutation       LLR   Kd_avg
# 1   esm2_t36_3B_UR50D     V29F -1.799312    139.9
# 9   esm2_t36_3B_UR50D     K32Y  0.507355  31772.0
# 17  esm2_t36_3B_UR50D     L51Y  0.106559    175.5
# 25  esm2_t36_3B_UR50D     D57T -3.202071      NaN
# 33  esm2_t36_3B_UR50D     A77T -3.129880    165.4
# 41  esm2_t36_3B_UR50D     G91A -2.748997    171.3
#
# Model: esm2_t6_8M_UR50D
#                Model Mutation       LLR   Kd_avg
# 2   esm2_t6_8M_UR50D     V29F -0.883637    139.9
# 10  esm2_t6_8M_UR50D     K32Y  0.320717  31772.0
# 18  esm2_t6_8M_UR50D     L51Y -0.865048    175.5
# 26  esm2_t6_8M_UR50D     D57T -0.556325      NaN
# 34  esm2_t6_8M_UR50D     A77T  0.018493    165.4
# 42  esm2_t6_8M_UR50D     G91A -0.023172    171.3
#
# Model: progen2-large
#             Model Mutation       LLR   Kd_avg
# 3   progen2-large     V29F -4.859660    139.9
# 11  progen2-large     K32Y -1.289848  31772.0
# 19  progen2-large     L51Y -2.116316    175.5
# 27  progen2-large     D57T  1.895473      NaN
# 35  progen2-large     A77T  0.000000    165.4
# 43  progen2-large     G91A  3.507758    171.3
#
# Model: progen2-medium
#              Model Mutation       LLR   Kd_avg
# 4   progen2-medium     V29F -2.865700    139.9
# 12  progen2-medium     K32Y  1.919304  31772.0
# 20  progen2-medium     L51Y -1.515060    175.5
# 28  progen2-medium     D57T  0.979255      NaN
# 36  progen2-medium     A77T  0.000000    165.4
# 44  progen2-medium     G91A  4.076111    171.3
#
# Model: progen2-oas
#           Model Mutation       LLR   Kd_avg
# 5   progen2-oas     V29F -4.392662    139.9
# 13  progen2-oas     K32Y -3.030834  31772.0
# 21  progen2-oas     L51Y -4.793731    175.5
# 29  progen2-oas     D57T  4.943764      NaN
# 37  progen2-oas     A77T  0.000000    165.4
# 45  progen2-oas     G91A  4.116261    171.3
#
# Model: progen2-small
#             Model Mutation       LLR   Kd_avg
# 6   progen2-small     V29F -1.637257    139.9
# 14  progen2-small     K32Y  2.479523  31772.0
# 22  progen2-small     L51Y -1.253754    175.5
# 30  progen2-small     D57T -1.769920      NaN
# 38  progen2-small     A77T  0.000000    165.4
# 46  progen2-small     G91A  5.042107    171.3
#
# === Grouped by Model: S309 ===
#
# Model: esm1b_t33_650M_UR50S
#                    Model Mutation       LLR  Kd_avg
# 0   esm1b_t33_650M_UR50S     P28T -6.599962   3.233
# 8   esm1b_t33_650M_UR50S     T77N -2.151127   2.679
# 16  esm1b_t33_650M_UR50S     G79A -5.091761   3.175
# 24  esm1b_t33_650M_UR50S     R84S -6.803185   2.759
# 32  esm1b_t33_650M_UR50S     R85S  0.856491   3.214
# 40  esm1b_t33_650M_UR50S     R87T -7.639145   2.243
#
# Model: esm2_t33_650M_UR50D
#                   Model Mutation        LLR  Kd_avg
# 1   esm2_t33_650M_UR50D     P28T  -8.155033   3.233
# 9   esm2_t33_650M_UR50D     T77N  -0.129403   2.679
# 17  esm2_t33_650M_UR50D     G79A  -4.706926   3.175
# 25  esm2_t33_650M_UR50D     R84S -13.400880   2.759
# 33  esm2_t33_650M_UR50D     R85S  -0.821234   3.214
# 41  esm2_t33_650M_UR50D     R87T  -8.459522   2.243
#
# Model: esm2_t36_3B_UR50D
#                 Model Mutation        LLR  Kd_avg
# 2   esm2_t36_3B_UR50D     P28T  -5.837529   3.233
# 10  esm2_t36_3B_UR50D     T77N  -2.269230   2.679
# 18  esm2_t36_3B_UR50D     G79A  -5.714510   3.175
# 26  esm2_t36_3B_UR50D     R84S -10.779812   2.759
# 34  esm2_t36_3B_UR50D     R85S  -2.212835   3.214
# 42  esm2_t36_3B_UR50D     R87T  -9.745874   2.243
#
# Model: esm2_t6_8M_UR50D
#                Model Mutation       LLR  Kd_avg
# 4   esm2_t6_8M_UR50D     P28T  0.405215   3.233
# 12  esm2_t6_8M_UR50D     T77N -0.249976   2.679
# 20  esm2_t6_8M_UR50D     G79A -0.829844   3.175
# 28  esm2_t6_8M_UR50D     R84S -4.224193   2.759
# 36  esm2_t6_8M_UR50D     R85S -0.795666   3.214
# 44  esm2_t6_8M_UR50D     R87T -1.007753   2.243
#
# Model: progen2-large
#             Model Mutation       LLR  Kd_avg
# 3   progen2-large     P28T  1.747067   3.233
# 11  progen2-large     T77N -3.307592   2.679
# 19  progen2-large     G79A  3.728068   3.175
# 27  progen2-large     R84S -7.253824   2.759
# 35  progen2-large     R85S -2.060616   3.214
# 43  progen2-large     R87T -5.899165   2.243
#
# Model: progen2-medium
#              Model Mutation       LLR  Kd_avg
# 5   progen2-medium     P28T  2.244819   3.233
# 13  progen2-medium     T77N -1.480210   2.679
# 21  progen2-medium     G79A  4.374618   3.175
# 29  progen2-medium     R84S -3.034905   2.759
# 37  progen2-medium     R85S -2.187210   3.214
# 45  progen2-medium     R87T -3.777687   2.243
#
# Model: progen2-oas
#           Model Mutation       LLR  Kd_avg
# 6   progen2-oas     P28T -1.581955   3.233
# 14  progen2-oas     T77N -4.431137   2.679
# 22  progen2-oas     G79A  3.453724   3.175
# 30  progen2-oas     R84S -8.091511   2.759
# 38  progen2-oas     R85S -3.593910   3.214
# 46  progen2-oas     R87T -6.260361   2.243
#
# Model: progen2-small
#             Model Mutation       LLR  Kd_avg
# 7   progen2-small     P28T  1.921638   3.233
# 15  progen2-small     T77N -1.065712   2.679
# 23  progen2-small     G79A  4.311413   3.175
# 31  progen2-small     R84S -1.794563   2.759
# 39  progen2-small     R85S -0.375362   3.214
# 47  progen2-small     R87T -0.182800   2.243

# %%
from scipy.stats import spearmanr

def run_spearman(grouped_df, antibody_name):
    print(f"\n=== Spearman Correlation for {antibody_name} ===")
    for model, group in grouped_df:
        # Drop rows with missing Kd_avg or non-numeric LLRs
        filtered = group.dropna(subset=["LLR", "Kd_avg"])

        if len(filtered) < 2:
            print(f"\nModel: {model} — Not enough data for correlation")
            continue

        llr_vals = filtered["LLR"].astype(float)
        kd_vals = filtered["Kd_avg"].astype(float)

        rho, pval = spearmanr(llr_vals, kd_vals)

        print(f"\nModel: {model}")
        print(f"  Spearman rho = {rho:.4f}")
        print(f"  p-value      = {pval:.4f}")

# %%
run_spearman(grouped_medi8852, "MEDI8852")
run_spearman(grouped_c143, "C143")
run_spearman(grouped_s309, "S309")
# Out:
# === Spearman Correlation for MEDI8852 ===
#
# Model: esm1b_t33_650M_UR50S
#   Spearman rho = -0.1078
#   p-value      = 0.7995
#
# Model: esm2_t33_650M_UR50D
#   Spearman rho = -0.2515
#   p-value      = 0.5479
#
# Model: esm2_t36_3B_UR50D
#   Spearman rho = -0.2755
#   p-value      = 0.5091
#
# Model: esm2_t6_8M_UR50D
#   Spearman rho = -0.0599
#   p-value      = 0.8880
#
# Model: progen2-large
#   Spearman rho = 0.0000
#   p-value      = 1.0000
#
# Model: progen2-medium
#   Spearman rho = -0.0952
#   p-value      = 0.8225
#
# Model: progen2-oas
#   Spearman rho = -0.0238
#   p-value      = 0.9554
#
# Model: progen2-small
#   Spearman rho = -0.5476
#   p-value      = 0.1600
#
# === Spearman Correlation for C143 ===
#
# Model: esm1b_t33_650M_UR50S
#   Spearman rho = 0.6000
#   p-value      = 0.2848
#
# Model: esm2_t33_650M_UR50D
#   Spearman rho = 0.6000
#   p-value      = 0.2848
#
# Model: esm2_t36_3B_UR50D
#   Spearman rho = 0.7000
#   p-value      = 0.1881
#
# Model: esm2_t6_8M_UR50D
#   Spearman rho = 0.6000
#   p-value      = 0.2848
#
# Model: progen2-large
#   Spearman rho = 0.2000
#   p-value      = 0.7471
#
# Model: progen2-medium
#   Spearman rho = 0.5000
#   p-value      = 0.3910
#
# Model: progen2-oas
#   Spearman rho = -0.1000
#   p-value      = 0.8729
#
# Model: progen2-small
#   Spearman rho = 0.5000
#   p-value      = 0.3910
#
# === Spearman Correlation for S309 ===
#
# Model: esm1b_t33_650M_UR50S
#   Spearman rho = 0.4286
#   p-value      = 0.3965
#
# Model: esm2_t33_650M_UR50D
#   Spearman rho = 0.1429
#   p-value      = 0.7872
#
# Model: esm2_t36_3B_UR50D
#   Spearman rho = 0.3143
#   p-value      = 0.5441
#
# Model: esm2_t6_8M_UR50D
#   Spearman rho = 0.5429
#   p-value      = 0.2657
#
# Model: progen2-large
#   Spearman rho = 0.6571
#   p-value      = 0.1562
#
# Model: progen2-medium
#   Spearman rho = 0.6000
#   p-value      = 0.2080
#
# Model: progen2-oas
#   Spearman rho = 0.6571
#   p-value      = 0.1562
#
# Model: progen2-small
#   Spearman rho = 0.3714
#   p-value      = 0.4685

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

data = {
    "MEDI8852": {
        "esm1b_t33_650M_UR50S": (-0.1078, 0.7995),
        "esm2_t33_650M_UR50D": (-0.2515, 0.5479),
        "esm2_t36_3B_UR50D": (-0.2755, 0.5091),
        "esm2_t6_8M_UR50D": (-0.0599, 0.8880),
        "progen2-large": (0.0000, 1.0000),
        "progen2-medium": (-0.0952, 0.8225),
        "progen2-oas": (-0.0238, 0.9554),
        "progen2-small": (-0.5476, 0.1600),
    },
    "C143": {
        "esm1b_t33_650M_UR50S": (0.6000, 0.2848),
        "esm2_t33_650M_UR50D": (0.6000, 0.2848),
        "esm2_t36_3B_UR50D": (0.7000, 0.1881),
        "esm2_t6_8M_UR50D": (0.6000, 0.2848),
        "progen2-large": (0.2000, 0.7471),
        "progen2-medium": (0.5000, 0.3910),
        "progen2-oas": (-0.1000, 0.8729),
        "progen2-small": (0.5000, 0.3910),
    },
    "S309": {
        "esm1b_t33_650M_UR50S": (0.4286, 0.3965),
        "esm2_t33_650M_UR50D": (0.1429, 0.7872),
        "esm2_t36_3B_UR50D": (0.3143, 0.5441),
        "esm2_t6_8M_UR50D": (0.5429, 0.2657),
        "progen2-large": (0.6571, 0.1562),
        "progen2-medium": (0.6000, 0.2080),
        "progen2-oas": (0.6571, 0.1562),
        "progen2-small": (0.3714, 0.4685),
    }
}

# Prepare a DataFrame
records = []
for antibody, models in data.items():
    for model, (rho, pval) in models.items():
        records.append({"Antibody": antibody, "Model": model, "Rho": rho, "p-value": pval})

df = pd.DataFrame(records)

# Create a heatmap-like plot with annotations
pivot_rho = df.pivot(index="Model", columns="Antibody", values="Rho")

plt.figure(figsize=(10, 6))
ax = sns.heatmap(pivot_rho, annot=True, fmt=".2f", cmap="coolwarm", center=0, linewidths=.5, cbar_kws={"label": "Spearman Rho"})
plt.title("Spearman Correlation (LLR vs Kd_avg) per Model")
plt.ylabel("Model")
plt.xlabel("Antibody")
plt.savefig("spearmanCorrelationLLRkd.png", format="png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Create a heatmap for the p-values
pivot_pval = df.pivot(index="Model", columns="Antibody", values="p-value")

plt.figure(figsize=(10, 6))
ax = sns.heatmap(pivot_pval, annot=True, fmt=".4f", cmap="YlGnBu", cbar_kws={"label": "p-value"}, linewidths=.5)

# Highlight significant values (p < 0.05) by outlining or changing color
for y in range(pivot_pval.shape[0]):
    for x in range(pivot_pval.shape[1]):
        val = pivot_pval.iloc[y, x]
        if val < 0.05:
            ax.add_patch(plt.Rectangle((x, y), 1, 1, fill=False, edgecolor='red', lw=2))

plt.title("Spearman Correlation p-values (LLR vs Kd_avg)")
plt.ylabel("Model")
plt.xlabel("Antibody")
plt.tight_layout()
plt.show()
